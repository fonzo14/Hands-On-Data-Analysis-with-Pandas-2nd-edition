# %%
import pandas as pd

# %%
df = pd.read_csv('data/parsed.csv')
df
# Out:
#      alert  cdi        code  \
# 0      NaN  NaN    37389218
# 1      NaN  NaN    37389202
# 2      NaN  4.4    37389194
# 3      NaN  NaN    37389186
# 4      NaN  NaN    73096941
# ...    ...  ...         ...
# 9327   NaN  NaN    73086771
# 9328   NaN  NaN    38063967
# 9329   NaN  NaN  2018261000
# 9330   NaN  NaN    38063959
# 9331   NaN  NaN    38063935
#
#                                                  detail      dmin  felt  \
# 0     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.008693   NaN
# 1     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.020030   NaN
# 2     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.021370  28.0
# 3     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.026180   NaN
# 4     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.077990   NaN
# ...                                                 ...       ...   ...
# 9327  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.018060   NaN
# ...

# %%
df.columns
# Out:
# Index(['alert', 'cdi', 'code', 'detail', 'dmin', 'felt', 'gap', 'ids', 'mag',
#        'magType', 'mmi', 'net', 'nst', 'place', 'rms', 'sig', 'sources',
#        'status', 'time', 'title', 'tsunami', 'type', 'types', 'tz', 'updated',
#        'url', 'parsed_place'],
#       dtype='object')

# %%
df[['mag', 'magType','place']][(df.place.str.contains('Japan')) & (df.magType == 'mb')].sample(3)
# Out:
#       mag magType                        place
# 7261  4.1      mb     64km ESE of Owase, Japan
# 8324  4.6      mb       167km E of Nago, Japan
# 1124  4.6      mb  53km ESE of Kamaishi, Japan

# %%
df[['mag', 'magType','place']][(df.place.str.contains('Japan')) & (df.magType == 'mb')].describe()
# Out:
#              mag
# count  50.000000
# mean    4.530000
# std     0.266688
# min     4.000000
# 25%     4.400000
# 50%     4.600000
# 75%     4.700000
# max     5.400000

# %%
df[['mag', 'magType','place']][(df.place.str.contains('Japan')) & (df.magType == 'mb')].describe(percentiles=[0.05,0.95])
# Out:
#              mag
# count  50.000000
# mean    4.530000
# std     0.266688
# min     4.000000
# 5%      4.100000
# 50%     4.600000
# 95%     4.900000
# max     5.400000

# %%
percentile_95 = df[['mag', 'magType','place']][(df.place.str.contains('Japan')) & (df.magType == 'mb')].mag.quantile(0.95)
percentile_95
# Out:
# 4.9

# %%
df[df.place.str.contains('Indonesia')]['tsunami'].value_counts(normalize=True).iloc[1]
# Out:
# 0.23129251700680273

# %%
df[df.place.str.contains('Nevada')].describe()
# Out:
#              cdi        dmin       felt         gap         mag   mmi  \
# count  15.000000  677.000000  15.000000  677.000000  677.000000  1.00
# mean    2.440000    0.166982   2.400000  154.029527    0.491728  2.84
# std     0.501142    0.166400   4.626013   68.769713    0.689560   NaN
# min     2.000000    0.001000   1.000000   29.140000   -0.500000  2.84
# 25%     2.000000    0.054000   1.000000   97.670000   -0.100000  2.84
# 50%     2.200000    0.113000   1.000000  149.550000    0.400000  2.84
# 75%     2.900000    0.234000   1.000000  200.470000    0.900000  2.84
# max     3.300000    1.414000  19.000000  355.910000    2.900000  2.84
#
#               nst         rms         sig          time  tsunami     tz  \
# count  677.000000  677.000000  677.000000  6.770000e+02    677.0  677.0
# mean    12.608567    0.151909   10.688331  1.538314e+12      0.0 -480.0
# std      9.890620    0.084742   19.252727  5.954070e+08      0.0    0.0
# ...

# %%
df['ringoffire'] = ~df.parsed_place.str.contains('New Mexico') & df.parsed_place.str.contains(r'Alaska|Antarctic|Bolivia|California|Canada|Chile|Costa Rica|Ecuador|Fiji|Guatemala|Indonesia|Japan|Kermadec Islands|Mexico|New Zealand|Peru|Philippines|Russia|Taiwan|Tonga|Washington')

# %%
df
# Out:
#      alert  cdi        code  \
# 0      NaN  NaN    37389218
# 1      NaN  NaN    37389202
# 2      NaN  4.4    37389194
# 3      NaN  NaN    37389186
# 4      NaN  NaN    73096941
# ...    ...  ...         ...
# 9327   NaN  NaN    73086771
# 9328   NaN  NaN    38063967
# 9329   NaN  NaN  2018261000
# 9330   NaN  NaN    38063959
# 9331   NaN  NaN    38063935
#
#                                                  detail      dmin  felt  \
# 0     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.008693   NaN
# 1     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.020030   NaN
# 2     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.021370  28.0
# 3     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.026180   NaN
# 4     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.077990   NaN
# ...                                                 ...       ...   ...
# 9327  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.018060   NaN
# ...

# %%
df.ringoffire.value_counts()
# Out:
# True     7188
# False    2144
# Name: ringoffire, dtype: int64

# %%
df[(df.ringoffire == True) & (df.tsunami == 1)].shape[0]
# Out:
# 45

# %%
df.loc[df.ringoffire,'tsunami'].sum()
# Out:
# 45
